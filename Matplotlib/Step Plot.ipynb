# %%
import matplotlib.pyplot as plt

x=["day1","day2","day3","day4","day5"]
y=[30,40,25,30,40]

plt.step(x,y,marker="o")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
data=pd.read_excel("detail.xlsx")
df=pd.DataFrame(data)
print(df)

group=df.groupby
# Out:
#    Unnamed: 0   EEID      Name gender   salary
# 0           0  EMP01    ayushi      F      NaN
# 1           1  EMP02     ziyan      M  25000.0
# 2           2  EMP03  pranjali    NaN  27000.0
# 3           3  EMP01    faraaz      F  20000.0
# 4           4  EMP05       NaN      M  25000.0
# 5           5  EMP06     karan      M      NaN
# 6           6  EMP02     karan      M  25000.0
