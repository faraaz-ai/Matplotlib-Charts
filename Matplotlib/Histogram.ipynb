# %%
import matplotlib.pyplot as plt
x=[30,40,68,27,47,88,44,23,44,66,66,33,5,2,5,50,12,17,16]

plt.hist(x, bins = 15,edgecolor="black",color="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.pd.read_excel("detail.xlsx")
df=pd.DataFrame(data)
print(df)

plt.hist(df["gender"], bins=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 data=pd.pd.read_excel("detail.xlsx")
#       5 df=pd.DataFrame(data)
#       6 print(df)
#
# AttributeError: module 'pandas' has no attribute 'pd'
